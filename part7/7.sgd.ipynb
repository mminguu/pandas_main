# %% [markdown]
# #### 확률적 경사하강법 SGD
# '''
# 모델의 오차(비용) 를 최소화 하는 파라메터(가중치)를 찾기 위한 최적화 방법
# 현재 위치 : 모델의 현재 파라메터가 됨
# 산의 높이 : 모델의 오차
# 기울기 : 반대방향으로 가야 가장 빠르게 낮아진다.
# '''
# '''
# 배치경사 하강법 : 산 전체의 지형을 모두 조사해서 가장 가파른 방향을 찾아 한걸음씩 내려가는 구조
# (한번에 전체 데이터를 다 쓴다.)
# 장점 : 전체 데이터를 다 쓰기 때문에 기울기 계산이 매우 정확함
# 단점 : 데이터가 많기 때문에 계산이 느리고 리소스를 많이 사용함
#
# 확률적 경사하강법 : 무작위로 한 지점만 보고 그곳의 경사를 따라서 내려간다.
# SGD 는 무작위로 샘플 1개의 오차를 계산하고 파라메터를 업데이트함. 이 과정을 모든 데이터에 대해서 빠르게 반복.
# 장점 :  지역최저점(local minimum) 에 갇히지 않고 더 낮은 전역최저점(global minimum)
# 단점 :  잘못된 방향으로 갈 수 있음
# '''

# %% [markdown]
# '''
# W-new : 새로운 가중치
# W-old : 현재 가중치
# n(에타) : 학습률 learning late.  /  너무 크면 최저점을 지나고 너무 작으면 학습이 매우 느려짐.
# 나블라▽ : 기울기 Gradient
# J : 오차함수(비용함수)  현재 가중치 W-old에서 하나의 데이터 샘플에 대한 오차
#
# 기울기가 작으면 시간도 많이 걸리고 계산이 오래걸리지만 값이 정확함.
#
# 새로운 가중치 = 현재 가중치 오차를 키우는 기울기 방향과 반대로 학습률만큼 이동한 값
# '''

# %%
# y = Wx
# 비용함수는 오차  (Wx - y)**2 / 2 수식을 미분 (Wx - y)*x
